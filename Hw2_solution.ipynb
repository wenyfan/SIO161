# %%
import numpy as np

print('homework 2')
# Out:
# homework 2

# %%
# questions1
r0 = 6357e3 # m
r1 = r0-30e3
print(r0,r1)

A = np.pi*(r0**2-r1**2) # m^2
print(A)

mu = 30e9
D = 20
m0 = mu*D*A
print(m0)

mw = 2/3*(np.log10(m0)-9.1)
print(mw)
# Out:
# 6357000.0 6327000.0
# 1195438836543.988
# 7.172633019263929e+23
# 9.837119074101661

# %%
# question2
m0_1 = 2.6e18
mw_1 =2/3*(np.log10(m0_1)-9.1)
print(mw_1)

m0_2 = 3e13/3e12*7/10*2.6e18 # i'm too lazy to go through converting the time, so i just take the ratio and multiple the atlantic hurricane energy
mw_2 =2/3*(np.log10(m0_2)-9.1)
print(mw_2)
# Out:
# 6.209982231980545
# 6.773380925323384

# %%
# question3
e2020 = 3.8e12*3.6e6
mw_e2020 =2/3*(np.log10(e2020)-9.1)
print(mw_e2020)

e1950 = e2020/13
mw_e1950 =2/3*(np.log10(e1950)-9.1)
print(mw_e1950)
# Out:
# 6.6907240649227315
# 5.94809516338484

# %%
# question4
w=10e3
Dbar=4

L1 = e2020/w/Dbar/mu
print(L1)

L2 = e1950/w/Dbar/mu
print(L2)
# Out:
# 11400.0
# 876.9230769230769
