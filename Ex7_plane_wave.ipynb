# %%
import numpy as np
import matplotlib.pyplot as plt

print('Harmonic plane wave')
# Out:
# Harmonic plane wave

# %%
freq = 1
omega = np.pi*2*freq
V = 6
s = 1/v
A = 10

x0 = 3

t = np.arange(x0/V,3,0.01)

u3_t= A*np.cos(2*np.pi*(t-x0/V))

plt.plot(t, u3_t, '-')

# %%
t0 = 3

x = np.arange(0,t0*V,0.01)

ux_3= A*np.cos(2*np.pi*(t0-x/V))

plt.plot(x, ux_3, '-')
